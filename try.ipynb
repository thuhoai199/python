# %% [markdown]
# # 初めてのノートプック
# **コードをきいてみましょう**

# %%
#計算する
2*(3+4)
# Out:
# 14

# %% [markdown]
# *出力してみましょう*
#  # first value:1

# %%
'''
値を出力する
'''
a = 1
print('first value:', a)
# Out:
# first value: 1

# %%
a = 100
print('day la a',a)
# Out:
# day la a 100

# %% [markdown]
# **`sort`の関数を呼び出す**
# 1. 以下ノリストを作る
# numbers= [4,3,2,1]
# 2. `sort()`ノリスト関数を使って、リストヲソートする。
# 3.`print`を使って、出力する。

# %%
これはコードとして書
